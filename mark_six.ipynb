# %%
import pandas as pd

# %%
raw_data = pd.read_csv("/content/Mark_Six.txt", sep="\t")

### Filter Columns
MarkSixHist = raw_data.iloc[:, :8]

### Renamce columns
MarkSixHist = MarkSixHist.rename(columns={"Winning Number 1": "1"})

###

MarkSixHist.head()
# Out:
#      Draw        Date   1   2   3   4   5   6
# 0  25/014  2025-02-08   1   7  21  27  33  45
# 1  25/013  2025-02-06   1   4  18  25  38  45
# 2  25/012  2025-02-04   3  13  15  18  19  24
# 3  25/011  2025-02-02  14  18  30  36  40  42
# 4  25/010  2025-01-25   7  14  19  31  36  45

# %%
# from datetime import datetime

# weekday_dict = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}

# MarkSixHist["weekdate"] = MarkSixHist["Date"].apply(lambda x: weekday_dict[datetime.strptime(x, "%Y-%m-%d").date().weekday()])
# MarkSixHist.head()

MarkSixHist.dtypes
# Out:
# Draw    object
# Date    object
# 1        int64
# 2        int64
# 3        int64
# 4        int64
# 5        int64
# 6        int64
# dtype: object
